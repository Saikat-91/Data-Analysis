# %% [markdown]
# ## EDA : Exploratory Data Analysis

# %% [markdown]
# ## <center>**Flipkart Sales Data Analysis**</center>

# %% [markdown]
# ## **Table of Contents**
#
# 1. [**Importing Packages**](#section1)<br>
# 2. [**Loading Data**](#section2)<br>
# 3. [**Description of the Dataset**](#section3)<br>
# 4. [**Data Preprocessing**](#section4)<br>
# 5. [**Exploratory Data Analysis**](#section5)<br>
# 6. [**Conclusion**](#section6)<br>

# %% [markdown]
# <a id=section1></a>
#
# ---
# # **1. Importing Libraries**
# ---

# %%
import numpy as np

#--------------------------------------------------------------------------------
import pandas as pd

#--------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

#---------------------------------------------------------------------------------------------------------------
from urllib.parse import quote_plus                     # mysql workbench connection from python libraries
from sqlalchemy import create_engine
from sqlalchemy import text

#--------------------------------------------------------------------------------
from getpass import getpass                          # for password hide

# %% [markdown]
# <a id=section2></a>
#
# ---
# # **2. Loading Data**
# ---

# %%
password = getpass('Enter the password : ')
# Out:
# Enter the password :  ········

# %%
# establish connection with the database 
engine = create_engine(f"""mysql+mysqlconnector://root:{quote_plus(password)}@localhost:3306/flipkat_sales""")

# %%
# read table data using sql query 
sql_data = pd.read_sql_query(text("select * from flipkart_mobile;"),con =engine.connect())
sql_data
# Out:
#      product_id    brand           model base_color processor screen_size  \
# 0             1    Apple       iPhone SE      Black     Water  Very Small
# 1             2    Apple  iPhone 12 Mini        Red   Ceramic       Small
# 2             3    Apple       iPhone SE        Red     Water  Very Small
# 3             4    Apple       iPhone XR     Others       iOS      Medium
# 4             5    Apple       iPhone 12        Red   Ceramic      Medium
# ..          ...      ...             ...        ...       ...         ...
# 425         426  Samsung      Galaxy A20      Black    Exynos      Medium
# 426         427  Samsung   Galaxy A22 5G     Others  MediaTek       Large
# 427         428  Samsung     Galaxy F02s       Blue  Qualcomm       Large
# 428         429  Samsung      Galaxy F62       Blue    Exynos       Large
# 429         430  Samsung      Galaxy F41      Green    Exynos      Medium
#
#      ROM  RAM  display_size  num_rear_camera  num_front_camera  \
# 0     64    2           4.7                1                 1
# 1     64    4           5.4                2                 1
# 2     64    2           4.7                1                 1
# 3     64    3           6.1                1                 1
# 4    128    4           6.1                2                 1
# ..   ...  ...           ...              ...               ...
# 425   32    3           6.4                2                 1
# 426  128    8           6.6                3                 1
# 427   32    3           6.5                3                 1
# 428  128    8           6.7                4                 1
# 429  128    6           6.4                3                 1
#
#      battery_capacity  ratings  num_of_ratings  sale_price_before_discount  \
# 0                1800      4.5           38645                       32999
# 1                2815      4.5             244                       57149
# 2                1800      4.5           38645                       32999
# 3                2942      4.6            5366                       42999
# 4                2815      4.6             745                       69149
# ..                ...      ...             ...                         ...
# 425              4000      4.3           15519                       11490
# 426              5000      NaN              26                       21999
# 427              5000      4.2             683                        9499
# 428              7000      4.3            4746                       25999
# 429              6000      NaN           61812                       14499
#
#      discount_percent  total_sales_before_discount_crore payment_method  \
# 0                17.0                             127.52            UPI
# 1                 4.0                               1.39    Credit Card
# 2                17.0                             127.52    Net Banking
# 3                10.0                              23.07            UPI
# 4                 2.0                               5.15            COD
# ..                ...                                ...            ...
# 425              10.0                              17.83    Credit Card
# 426               8.0                               0.06            COD
# 427               9.0                               0.65            UPI
# 428              18.0                              12.34            COD
# 429              30.0                              89.62     Debit Card
#
#               state       city
# 0     Uttar Pradesh    Mathura
# 1             Delhi      Delhi
# 2     Uttar Pradesh    Mathura
# 3       Maharashtra     Mumbai
# 4    Madhya Pradesh     Indore
# ..              ...        ...
# 425         Gujarat      Surat
# 426  Andhra Pradesh  Hyderabad
# 427  Madhya Pradesh     Indore
# 428           Bihar      Patna
# 429        Nagaland     Kohima
#
# [430 rows x 20 columns]

# %% [markdown]
# <a id=section3></a>
#
# ---
# # **3. Data Description**
# ---

# %%
# Shape of DataFrame (Column and Row) 
sql_data.shape
# Out:
# (430, 20)

# %%
# Checking the all columns data types and their Non-Null Value Count
sql_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430 entries, 0 to 429
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   product_id                         430 non-null    int64
#  1   brand                              430 non-null    object
#  2   model                              430 non-null    object
#  3   base_color                         430 non-null    object
#  4   processor                          430 non-null    object
#  5   screen_size                        430 non-null    object
#  6   ROM                                430 non-null    int64
#  7   RAM                                430 non-null    int64
#  8   display_size                       430 non-null    float64
#  9   num_rear_camera                    430 non-null    int64
#  10  num_front_camera                   430 non-null    int64
#  11  battery_capacity                   430 non-null    int64
#  12  ratings                            426 non-null    float64
#  13  num_of_ratings                     430 non-null    int64
#  14  sale_price_before_discount         430 non-null    int64
#  15  discount_percent                   430 non-null    float64
#  16  total_sales_before_discount_crore  430 non-null    float64
#  17  payment_method                     430 non-null    object
#  18  state                              430 non-null    object
#  19  city                               430 non-null    object
# dtypes: float64(4), int64(8), object(8)
# memory usage: 67.3+ KB

# %% [markdown]
# **Observations:**
#
# - We have **8 int64 data type** features, **4 float64 data type** features and **8 object data type** features in the independent features.

# %%
# Checking the null values of each columns
sql_data.isnull().sum() # 4 null values in 'num_of_ratings' column
# Out:
# product_id                           0
# brand                                0
# model                                0
# base_color                           0
# processor                            0
# screen_size                          0
# ROM                                  0
# RAM                                  0
# display_size                         0
# num_rear_camera                      0
# num_front_camera                     0
# battery_capacity                     0
# ratings                              4
# num_of_ratings                       0
# sale_price_before_discount           0
# discount_percent                     0
# total_sales_before_discount_crore    0
# payment_method                       0
# state                                0
# city                                 0
# dtype: int64

# %% [markdown]
# **Observations:**
#
# - We can see there is **4 null values** in the dataset(ratings column). Let's see what the profiling report says:

# %% [markdown]
# <a id=section4></a>
#
# ---
# # **4 Data Preprocessing**
# ---

# %% [markdown]
# <a id=section41></a>
#
# ---
# ## **4.1 Data Cleaning**
# ---

# %% [markdown]
# ### Null Imputaion

# %%
# null imputaion by updaing mode value
data_mode=sql_data["ratings"].mode()[0] # mode of "ratings" column values (4.3)
data_mode
# Out:
# 4.3

# %%
# mode imputation in null value in "ratings" column in DataFrame(sql_data)
sql_data["ratings"].fillna(data_mode,inplace=True)
sql_data.isnull().sum() # null value checking
# Out:
# C:\Users\Saikat Piplai\AppData\Local\Temp\ipykernel_13884\1522479299.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sql_data["ratings"].fillna(data_mode,inplace=True)
# product_id                           0
# brand                                0
# model                                0
# base_color                           0
# processor                            0
# screen_size                          0
# ROM                                  0
# RAM                                  0
# display_size                         0
# num_rear_camera                      0
# num_front_camera                     0
# battery_capacity                     0
# ratings                              0
# num_of_ratings                       0
# sale_price_before_discount           0
# discount_percent                     0
# total_sales_before_discount_crore    0
# payment_method                       0
# state                                0
# city                                 0
# dtype: int64

# %% [markdown]
# **Observations:**
#
# - We have **succesfully imputed null values**

# %%
sql_data.tail(10)
# Out:
#      product_id    brand           model base_color processor screen_size  \
# 420         421  Samsung       Galaxy J6       Blue    Exynos       Small
# 421         422  Samsung   Galaxy J7 - 6     Others    Exynos       Small
# 422         423  Samsung      Galaxy A10       Blue    Exynos      Medium
# 423         424  Samsung  Galaxy Grand 2      Black  Qualcomm       Small
# 424         425  Samsung   Galaxy J7 - 6     Others    Exynos       Small
# 425         426  Samsung      Galaxy A20      Black    Exynos      Medium
# 426         427  Samsung   Galaxy A22 5G     Others  MediaTek       Large
# 427         428  Samsung     Galaxy F02s       Blue  Qualcomm       Large
# 428         429  Samsung      Galaxy F62       Blue    Exynos       Large
# 429         430  Samsung      Galaxy F41      Green    Exynos      Medium
#
#      ROM  RAM  display_size  num_rear_camera  num_front_camera  \
# 420   64    4           5.6                1                 1
# 421   16    2           5.5                1                 1
# 422   32    2           6.2                1                 1
# 423    8    1           5.2                1                 1
# 424   16    2           5.5                1                 1
# 425   32    3           6.4                2                 1
# 426  128    8           6.6                3                 1
# 427   32    3           6.5                3                 1
# 428  128    8           6.7                4                 1
# 429  128    6           6.4                3                 1
#
#      battery_capacity  ratings  num_of_ratings  sale_price_before_discount  \
# 420              3000      4.5           42278                        9490
# 421              3300      4.3           38916                       15299
# 422              3400      4.3           13112                        7990
# 423              2600      4.1            2343                       15999
# 424              3300      4.3           38916                       13800
# 425              4000      4.3           15519                       11490
# 426              5000      4.3              26                       21999
# 427              5000      4.2             683                        9499
# 428              7000      4.3            4746                       25999
# 429              6000      4.3           61812                       14499
#
#      discount_percent  total_sales_before_discount_crore payment_method  \
# 420              44.0                              40.12            COD
# 421               1.0                              59.54    Credit Card
# 422               8.0                              10.48    Credit Card
# 423               4.0                               3.75            COD
# 424               8.0                              53.70            UPI
# 425              10.0                              17.83    Credit Card
# 426               8.0                               0.06            COD
# 427               9.0                               0.65            UPI
# 428              18.0                              12.34            COD
# 429              30.0                              89.62     Debit Card
#
#               state       city
# 420     Maharashtra     Mumbai
# 421           Delhi      Delhi
# 422   Uttar Pradesh    Lucknow
# 423     West Bengal    Kolkata
# 424       Karnataka  Bangalore
# 425         Gujarat      Surat
# 426  Andhra Pradesh  Hyderabad
# 427  Madhya Pradesh     Indore
# 428           Bihar      Patna
# 429        Nagaland     Kohima

# %%
# insert a column sales_after_discount_crore in the DataFrame [logic = ((sales_crore*(100-discount_percent))/100) ] by using SQL Queries
sql_data = pd.read_sql_query(text("select a.*, round(((total_sales_before_discount_crore*(100-discount_percent))/100),2) as total_sales_after_discount_crore from flipkart_mobile a;"),con =engine.connect())
sql_data
# Out:
#      product_id    brand           model base_color processor screen_size  \
# 0             1    Apple       iPhone SE      Black     Water  Very Small
# 1             2    Apple  iPhone 12 Mini        Red   Ceramic       Small
# 2             3    Apple       iPhone SE        Red     Water  Very Small
# 3             4    Apple       iPhone XR     Others       iOS      Medium
# 4             5    Apple       iPhone 12        Red   Ceramic      Medium
# ..          ...      ...             ...        ...       ...         ...
# 425         426  Samsung      Galaxy A20      Black    Exynos      Medium
# 426         427  Samsung   Galaxy A22 5G     Others  MediaTek       Large
# 427         428  Samsung     Galaxy F02s       Blue  Qualcomm       Large
# 428         429  Samsung      Galaxy F62       Blue    Exynos       Large
# 429         430  Samsung      Galaxy F41      Green    Exynos      Medium
#
#      ROM  RAM  display_size  num_rear_camera  ...  battery_capacity  ratings  \
# 0     64    2           4.7                1  ...              1800      4.5
# 1     64    4           5.4                2  ...              2815      4.5
# 2     64    2           4.7                1  ...              1800      4.5
# 3     64    3           6.1                1  ...              2942      4.6
# 4    128    4           6.1                2  ...              2815      4.6
# ..   ...  ...           ...              ...  ...               ...      ...
# 425   32    3           6.4                2  ...              4000      4.3
# 426  128    8           6.6                3  ...              5000      NaN
# 427   32    3           6.5                3  ...              5000      4.2
# 428  128    8           6.7                4  ...              7000      4.3
# 429  128    6           6.4                3  ...              6000      NaN
#
#      num_of_ratings  sale_price_before_discount  discount_percent  \
# 0             38645                       32999              17.0
# 1               244                       57149               4.0
# 2             38645                       32999              17.0
# 3              5366                       42999              10.0
# 4               745                       69149               2.0
# ..              ...                         ...               ...
# 425           15519                       11490              10.0
# 426              26                       21999               8.0
# 427             683                        9499               9.0
# 428            4746                       25999              18.0
# 429           61812                       14499              30.0
#
#      total_sales_before_discount_crore  payment_method           state  \
# 0                               127.52             UPI   Uttar Pradesh
# 1                                 1.39     Credit Card           Delhi
# 2                               127.52     Net Banking   Uttar Pradesh
# 3                                23.07             UPI     Maharashtra
# 4                                 5.15             COD  Madhya Pradesh
# ..                                 ...             ...             ...
# 425                              17.83     Credit Card         Gujarat
# 426                               0.06             COD  Andhra Pradesh
# 427                               0.65             UPI  Madhya Pradesh
# 428                              12.34             COD           Bihar
# 429                              89.62      Debit Card        Nagaland
#
#           city total_sales_after_discount_crore
# 0      Mathura                           105.84
# 1        Delhi                             1.33
# 2      Mathura                           105.84
# 3       Mumbai                            20.76
# 4       Indore                             5.05
# ..         ...                              ...
# 425      Surat                            16.05
# 426  Hyderabad                             0.06
# 427     Indore                             0.59
# 428      Patna                            10.12
# 429     Kohima                            62.73
#
# [430 rows x 21 columns]

# %% [markdown]
# <a id=section5></a>
#
# ---
# # **5. Exploratory Data Analysis**
# ---

# %% [markdown]
# ## **EDA Questions**

# %% [markdown]
# ### Q1. Brandwise Sales of Mobile phones in 2023

# %%
# Data Set of Flipkart Mobile
sql_data.head()
# Out:
#    product_id  brand           model base_color processor screen_size  ROM  \
# 0           1  Apple       iPhone SE      Black     Water  Very Small   64
# 1           2  Apple  iPhone 12 Mini        Red   Ceramic       Small   64
# 2           3  Apple       iPhone SE        Red     Water  Very Small   64
# 3           4  Apple       iPhone XR     Others       iOS      Medium   64
# 4           5  Apple       iPhone 12        Red   Ceramic      Medium  128
#
#    RAM  display_size  num_rear_camera  ...  battery_capacity  ratings  \
# 0    2           4.7                1  ...              1800      4.5
# 1    4           5.4                2  ...              2815      4.5
# 2    2           4.7                1  ...              1800      4.5
# 3    3           6.1                1  ...              2942      4.6
# 4    4           6.1                2  ...              2815      4.6
#
#    num_of_ratings  sale_price_before_discount  discount_percent  \
# 0           38645                       32999              17.0
# 1             244                       57149               4.0
# 2           38645                       32999              17.0
# 3            5366                       42999              10.0
# 4             745                       69149               2.0
#
#    total_sales_before_discount_crore  payment_method           state     city  \
# 0                             127.52             UPI   Uttar Pradesh  Mathura
# 1                               1.39     Credit Card           Delhi    Delhi
# 2                             127.52     Net Banking   Uttar Pradesh  Mathura
# 3                              23.07             UPI     Maharashtra   Mumbai
# 4                               5.15             COD  Madhya Pradesh   Indore
#
#   total_sales_after_discount_crore
# 0                           105.84
# 1                             1.33
# 2                           105.84
# 3                            20.76
# 4                             5.05
#
# [5 rows x 21 columns]

# %%
# "brand" wise count in Flipkart Mobile Data Set
sql_data["brand"].value_counts().reset_index()
# Out:
#      brand  count
# 0   Realme    138
# 1  Samsung    119
# 2   Xiaomi     61
# 3    Apple     56
# 4     Poco     56

# %%
# "brand" wise grouping of "total_sales_after_discount_crore" in Flipkart Mobile Data Set
brand_wise_total_sales_after_discount_crore= sql_data.groupby("brand")["total_sales_after_discount_crore"].sum().reset_index()
brand_wise_total_sales_after_discount_crore
# Out:
#      brand  total_sales_after_discount_crore
# 0    Apple                            976.90
# 1     Poco                           2011.73
# 2   Realme                           3804.88
# 3  Samsung                           1001.70
# 4   Xiaomi                           3331.40

# %%
# bar plot 
plt.figure(figsize=(10,4)) # adjust the size of graph (w,h)---[w=weidth,h=height]
colors = np.random.rand(len(brand_wise_total_sales_after_discount_crore["brand"]), 3) # Generate random colors for each bar (Random RGB values)
barplot=plt.bar(brand_wise_total_sales_after_discount_crore["brand"],brand_wise_total_sales_after_discount_crore["total_sales_after_discount_crore"],color=colors) # graph ploting as bar graph
plt.bar_label(barplot,label_type="edge")  # value above the each bar
plt.xlabel("Brand Name") # x-axis name
plt.ylabel("Total Sales After Discount in crore") # y-axis name
plt.ylim([0,4500])
plt.title("Bar Plot") # title of the graph
plt.show() # not showing the text

# %% [markdown]
# **Observations**:
#
# - We have **5 Brand Groups** with in the data set => **Apple** , **Poco** , **Realme** , **Samsung** , **Xiaomi** .
# - From **DataFrame Analysis** we conclude that **Realme** has maximum number of **Total Sales After Discount in crore** (**3804.88**) .
# - From **DataFrame Analysis** we also conclude that **Apple** has minimum number of **Total Sales After Discount in crore** (**976.90**) .

# %% [markdown]
# ### Q2. Maximum discount percentage in brandwise mobiles

# %%
# Data Set of Flipkart Mobile
sql_data.head()
# Out:
#    product_id  brand           model base_color processor screen_size  ROM  \
# 0           1  Apple       iPhone SE      Black     Water  Very Small   64
# 1           2  Apple  iPhone 12 Mini        Red   Ceramic       Small   64
# 2           3  Apple       iPhone SE        Red     Water  Very Small   64
# 3           4  Apple       iPhone XR     Others       iOS      Medium   64
# 4           5  Apple       iPhone 12        Red   Ceramic      Medium  128
#
#    RAM  display_size  num_rear_camera  ...  battery_capacity  ratings  \
# 0    2           4.7                1  ...              1800      4.5
# 1    4           5.4                2  ...              2815      4.5
# 2    2           4.7                1  ...              1800      4.5
# 3    3           6.1                1  ...              2942      4.6
# 4    4           6.1                2  ...              2815      4.6
#
#    num_of_ratings  sale_price_before_discount  discount_percent  \
# 0           38645                       32999              17.0
# 1             244                       57149               4.0
# 2           38645                       32999              17.0
# 3            5366                       42999              10.0
# 4             745                       69149               2.0
#
#    total_sales_before_discount_crore  payment_method           state     city  \
# 0                             127.52             UPI   Uttar Pradesh  Mathura
# 1                               1.39     Credit Card           Delhi    Delhi
# 2                             127.52     Net Banking   Uttar Pradesh  Mathura
# 3                              23.07             UPI     Maharashtra   Mumbai
# 4                               5.15             COD  Madhya Pradesh   Indore
#
#   total_sales_after_discount_crore
# 0                           105.84
# 1                             1.33
# 2                           105.84
# 3                            20.76
# 4                             5.05
#
# [5 rows x 21 columns]

# %%
# "brand" wise grouping of "discount_percent" in Flipkart Mobile Data Set
brand_wise_discount_percent= round(sql_data.groupby("brand")["discount_percent"].mean(),2).reset_index() # also rounding 2 decimal point in mean of discount
brand_wise_discount_percent
# Out:
#      brand  discount_percent
# 0    Apple              6.43
# 1     Poco             16.21
# 2   Realme              8.44
# 3  Samsung             13.37
# 4   Xiaomi             10.16

# %%
# bar plot 
plt.figure(figsize=(10,4)) # adjust the size of graph (w,h)---[w=weidth,h=height]
colors = np.random.rand(len(brand_wise_discount_percent["brand"]), 3) # Generate random colors for each bar (Random RGB values)
barplot=plt.bar(brand_wise_discount_percent["brand"],round(brand_wise_discount_percent["discount_percent"],2),color=colors) # graph ploting as bar graph
plt.bar_label(barplot,label_type="edge")
plt.xlabel("Brand Nmae") # x-axis name
plt.ylabel("Discount Percent") # y-axis name
plt.ylim([0,20])
plt.xticks(rotation=45)  # rotation x-axis
plt.title("Bar Plot") # title of the graph
plt.show() # not showing the text

# %% [markdown]
# **Observations**:
#
# - We have **5 Brand Groups** with in the data set => **Apple** , **Poco** , **Realme** , **Samsung** , **Xiaomi** .
# - From **DataFrame Analysis** we conclude that **Poco** has maximum **Discount Percentage** (**16.21 %**) .
# - From **DataFrame Analysis** we also conclude that **Apple** has minimum **Discount Percentage** (**6.43 %**) .

# %% [markdown]
# ### Q3. Maximum discount amount in brandwise mobiles

# %%
# Data Set of Flipkart Mobile
sql_data.head()
# Out:
#    product_id  brand           model base_color processor screen_size  ROM  \
# 0           1  Apple       iPhone SE      Black     Water  Very Small   64
# 1           2  Apple  iPhone 12 Mini        Red   Ceramic       Small   64
# 2           3  Apple       iPhone SE        Red     Water  Very Small   64
# 3           4  Apple       iPhone XR     Others       iOS      Medium   64
# 4           5  Apple       iPhone 12        Red   Ceramic      Medium  128
#
#    RAM  display_size  num_rear_camera  ...  battery_capacity  ratings  \
# 0    2           4.7                1  ...              1800      4.5
# 1    4           5.4                2  ...              2815      4.5
# 2    2           4.7                1  ...              1800      4.5
# 3    3           6.1                1  ...              2942      4.6
# 4    4           6.1                2  ...              2815      4.6
#
#    num_of_ratings  sale_price_before_discount  discount_percent  \
# 0           38645                       32999              17.0
# 1             244                       57149               4.0
# 2           38645                       32999              17.0
# 3            5366                       42999              10.0
# 4             745                       69149               2.0
#
#    total_sales_before_discount_crore  payment_method           state     city  \
# 0                             127.52             UPI   Uttar Pradesh  Mathura
# 1                               1.39     Credit Card           Delhi    Delhi
# 2                             127.52     Net Banking   Uttar Pradesh  Mathura
# 3                              23.07             UPI     Maharashtra   Mumbai
# 4                               5.15             COD  Madhya Pradesh   Indore
#
#   total_sales_after_discount_crore
# 0                           105.84
# 1                             1.33
# 2                           105.84
# 3                            20.76
# 4                             5.05
#
# [5 rows x 21 columns]

# %%
# insert a column of discount_amount in the DataFrame by using Pandas
sql_data["discount_amount"]=sql_data["sale_price_before_discount"]*(sql_data["discount_percent"]/100)
sql_data.head()
# Out:
#    product_id  brand           model base_color processor screen_size  ROM  \
# 0           1  Apple       iPhone SE      Black     Water  Very Small   64
# 1           2  Apple  iPhone 12 Mini        Red   Ceramic       Small   64
# 2           3  Apple       iPhone SE        Red     Water  Very Small   64
# 3           4  Apple       iPhone XR     Others       iOS      Medium   64
# 4           5  Apple       iPhone 12        Red   Ceramic      Medium  128
#
#    RAM  display_size  num_rear_camera  ...  ratings  num_of_ratings  \
# 0    2           4.7                1  ...      4.5           38645
# 1    4           5.4                2  ...      4.5             244
# 2    2           4.7                1  ...      4.5           38645
# 3    3           6.1                1  ...      4.6            5366
# 4    4           6.1                2  ...      4.6             745
#
#    sale_price_before_discount  discount_percent  \
# 0                       32999              17.0
# 1                       57149               4.0
# 2                       32999              17.0
# 3                       42999              10.0
# 4                       69149               2.0
#
#    total_sales_before_discount_crore  payment_method           state     city  \
# 0                             127.52             UPI   Uttar Pradesh  Mathura
# 1                               1.39     Credit Card           Delhi    Delhi
# 2                             127.52     Net Banking   Uttar Pradesh  Mathura
# 3                              23.07             UPI     Maharashtra   Mumbai
# 4                               5.15             COD  Madhya Pradesh   Indore
#
#   total_sales_after_discount_crore discount_amount
# 0                           105.84         5609.83
# 1                             1.33         2285.96
# 2                           105.84         5609.83
# 3                            20.76         4299.90
# 4                             5.05         1382.98
#
# [5 rows x 22 columns]

# %%
# rearrange the DataFrame in proper maner in column wise
rearrange_data_frame =['brand', 'model', 'base_color', 'processor', 'screen_size', 'ROM', 'RAM', 'display_size', 'num_rear_camera', 'num_front_camera', 'battery_capacity', 'ratings',  'num_of_ratings', 'sale_price_before_discount', 'discount_percent', 'discount_amount', 'total_sales_before_discount_crore', 'total_sales_after_discount_crore','payment_method', 'state', 'city']  
sql_data=sql_data[rearrange_data_frame]
sql_data.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  ...  ratings  \
# 0           4.7                1                 1  ...      4.5
# 1           5.4                2                 1  ...      4.5
# 2           4.7                1                 1  ...      4.5
# 3           6.1                1                 1  ...      4.6
# 4           6.1                2                 1  ...      4.6
#
#    num_of_ratings  sale_price_before_discount  discount_percent  \
# 0           38645                       32999              17.0
# 1             244                       57149               4.0
# 2           38645                       32999              17.0
# 3            5366                       42999              10.0
# 4             745                       69149               2.0
#
#    discount_amount  total_sales_before_discount_crore  \
# 0          5609.83                             127.52
# 1          2285.96                               1.39
# 2          5609.83                             127.52
# 3          4299.90                              23.07
# 4          1382.98                               5.15
#
#    total_sales_after_discount_crore  payment_method           state     city
# 0                            105.84             UPI   Uttar Pradesh  Mathura
# 1                              1.33     Credit Card           Delhi    Delhi
# 2                            105.84     Net Banking   Uttar Pradesh  Mathura
# 3                             20.76             UPI     Maharashtra   Mumbai
# 4                              5.05             COD  Madhya Pradesh   Indore
#
# [5 rows x 21 columns]

# %%
# "brand" wise grouping of "discount_amount" in Flipkart Mobile Data Set
brand_wise_discount_amount= sql_data.groupby("brand")["discount_amount"].sum().reset_index()
brand_wise_discount_amount
# Out:
#      brand  discount_amount
# 0    Apple        187787.40
# 1     Poco        147000.92
# 2   Realme        181512.35
# 3  Samsung        496244.41
# 4   Xiaomi         97645.70

# %%
# bar plot 
plt.figure(figsize=(10,4)) # adjust the size of graph (w,h)---[w=weidth,h=height]
colors = np.random.rand(len(brand_wise_discount_amount["brand"]), 3) # Generate random colors for each bar (Random RGB values)
barplot=plt.bar(brand_wise_discount_amount["brand"],brand_wise_discount_amount["discount_amount"]/1000,color=colors) # graph ploting as bar graph
plt.bar_label(barplot,label_type="edge")
plt.xlabel("Brand Nmae") # x-axis name
plt.ylabel("Discount Amount in Thousand") # y-axis name
plt.ylim([0,600])
plt.title("Bar Plot") # title of the graph
plt.show() # not showing the text

# %% [markdown]
# **Observations**:
#
# - We have **5 Brand Groups** with in the data set => **Apple** , **Poco** , **Realme** , **Samsung** , **Xiaomi** .
# - From **DataFrame Analysis** we conclude that **Samsung** has maximum **Discount Amount** (**496244.41**) .
# - From **DataFrame Analysis** we also conclude that **Xiaomi** has minimum **Discount Amount** (**97645.70**) .

# %% [markdown]
# ### Q4. Brandwise Battery Capacity

# %%
# Data Set of Flipkart Mobile
sql_data.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  ...  ratings  \
# 0           4.7                1                 1  ...      4.5
# 1           5.4                2                 1  ...      4.5
# 2           4.7                1                 1  ...      4.5
# 3           6.1                1                 1  ...      4.6
# 4           6.1                2                 1  ...      4.6
#
#    num_of_ratings  sale_price_before_discount  discount_percent  \
# 0           38645                       32999              17.0
# 1             244                       57149               4.0
# 2           38645                       32999              17.0
# 3            5366                       42999              10.0
# 4             745                       69149               2.0
#
#    discount_amount  total_sales_before_discount_crore  \
# 0          5609.83                             127.52
# 1          2285.96                               1.39
# 2          5609.83                             127.52
# 3          4299.90                              23.07
# 4          1382.98                               5.15
#
#    total_sales_after_discount_crore  payment_method           state     city
# 0                            105.84             UPI   Uttar Pradesh  Mathura
# 1                              1.33     Credit Card           Delhi    Delhi
# 2                            105.84     Net Banking   Uttar Pradesh  Mathura
# 3                             20.76             UPI     Maharashtra   Mumbai
# 4                              5.05             COD  Madhya Pradesh   Indore
#
# [5 rows x 21 columns]

# %%
# "brand" wise grouping of "battery_capacity" in Flipkart Mobile Data Set
brand_wise_battery_capacity= round(sql_data.groupby("brand")["battery_capacity"].mean(),0).reset_index()
brand_wise_battery_capacity
# Out:
#      brand  battery_capacity
# 0    Apple            2765.0
# 1     Poco            5247.0
# 2   Realme            4797.0
# 3  Samsung            4846.0
# 4   Xiaomi            4266.0

# %%
# bar plot 
plt.figure(figsize=(10,4)) # adjust the size of graph (w,h)---[w=weidth,h=height]
colors = np.random.rand(len(brand_wise_battery_capacity["brand"]), 3) # Generate random colors for each bar (Random RGB values)
barplot=plt.bar(brand_wise_battery_capacity["brand"],brand_wise_battery_capacity["battery_capacity"],color=colors) # graph ploting as bar graph
plt.bar_label(barplot,label_type="edge")
plt.xlabel("Brand Nmae") # x-axis name
plt.ylabel("Battery Capacity in mAh") # y-axis name
plt.ylim([0,6000])
plt.title("Bar Plot") # title of the graph
plt.show() # not showing the text

# %% [markdown]
# **Observations**:
#
# - We have **5 Brand Groups** with in the data set => **Apple** , **Poco** , **Realme** , **Samsung** , **Xiaomi** .
# - From **DataFrame Analysis** we conclude that **Poco** has maximum **Battery Capacity in mAh** (**5247.0**) .
# - From **DataFrame Analysis** we also conclude that **Apple** has minimum **Battery Capacity in mAh** (**2765.0**) .

# %% [markdown]
# ### Q.5 Processor Wise Total Mobile Sales (In Percentage)

# %%
# Data Set of Flipkart Mobile
sql_data.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  ...  ratings  \
# 0           4.7                1                 1  ...      4.5
# 1           5.4                2                 1  ...      4.5
# 2           4.7                1                 1  ...      4.5
# 3           6.1                1                 1  ...      4.6
# 4           6.1                2                 1  ...      4.6
#
#    num_of_ratings  sale_price_before_discount  discount_percent  \
# 0           38645                       32999              17.0
# 1             244                       57149               4.0
# 2           38645                       32999              17.0
# 3            5366                       42999              10.0
# 4             745                       69149               2.0
#
#    discount_amount  total_sales_before_discount_crore  \
# 0          5609.83                             127.52
# 1          2285.96                               1.39
# 2          5609.83                             127.52
# 3          4299.90                              23.07
# 4          1382.98                               5.15
#
#    total_sales_after_discount_crore  payment_method           state     city
# 0                            105.84             UPI   Uttar Pradesh  Mathura
# 1                              1.33     Credit Card           Delhi    Delhi
# 2                            105.84     Net Banking   Uttar Pradesh  Mathura
# 3                             20.76             UPI     Maharashtra   Mumbai
# 4                              5.05             COD  Madhya Pradesh   Indore
#
# [5 rows x 21 columns]

# %%
# "processor" wise count in Flipkart Mobile Data Set
sql_data["processor"].value_counts()
# Out:
# processor
# Qualcomm    168
# MediaTek    144
# Exynos       53
# Ceramic      33
# iOS          12
# Water        11
# Others        9
# Name: count, dtype: int64

# %%
# "processor" wise grouping of "total_sales_after_discount_crore" in Flipkart Mobile Data Set
processor_wise_total_sales_after_discount_crore=sql_data.groupby("processor")["total_sales_after_discount_crore"].sum().reset_index()
processor_wise_total_sales_after_discount_crore
# Out:
#   processor  total_sales_after_discount_crore
# 0   Ceramic                            110.73
# 1    Exynos                            865.08
# 2  MediaTek                           3961.21
# 3    Others                             43.96
# 4  Qualcomm                           5279.46
# 5     Water                            494.32
# 6       iOS                            371.85

# %%
# Pi Chart
plt.figure(figsize=(9,10)) # adjust the size of graph (w,h)---[w=weidth,h=height]
plt.pie(processor_wise_total_sales_after_discount_crore['total_sales_after_discount_crore'],labels=processor_wise_total_sales_after_discount_crore['processor'],autopct='%1.2f%%') #"labels" is showing the pie chart lebel and "autopct" is parcentage showing in pie chart
plt.title('Processor Wise Mobile Sales in Percentage') # title of the graph
plt.legend(loc='upper right') #legend boxing and loc='upper right' is the position of the legend
plt.show()

# %% [markdown]
# **Observations**:
#
# - We have **7 Processor Groups** with in the data set => **Qualcomm** , **MediaTek** , **Exynos** , **Ceramic** , **iOS** , **Water** , **Others** .
# - From **DataFrame Analysis** we conclude that **Qualcomm** has maximum Percentage of **Total Sales After Discount Crore** (**47.45 %**) .
# - From **DataFrame Analysis** we also conclude that **Others** has minimum Percentage of **Total Sales After Discount Crore** (**0.40 %**) .

# %% [markdown]
# ### Q.6 Brand wise Screen Size Distribution

# %%
# Data Set of Flipkart Mobile
sql_data.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  ...  ratings  \
# 0           4.7                1                 1  ...      4.5
# 1           5.4                2                 1  ...      4.5
# 2           4.7                1                 1  ...      4.5
# 3           6.1                1                 1  ...      4.6
# 4           6.1                2                 1  ...      4.6
#
#    num_of_ratings  sale_price_before_discount  discount_percent  \
# 0           38645                       32999              17.0
# 1             244                       57149               4.0
# 2           38645                       32999              17.0
# 3            5366                       42999              10.0
# 4             745                       69149               2.0
#
#    discount_amount  total_sales_before_discount_crore  \
# 0          5609.83                             127.52
# 1          2285.96                               1.39
# 2          5609.83                             127.52
# 3          4299.90                              23.07
# 4          1382.98                               5.15
#
#    total_sales_after_discount_crore  payment_method           state     city
# 0                            105.84             UPI   Uttar Pradesh  Mathura
# 1                              1.33     Credit Card           Delhi    Delhi
# 2                            105.84     Net Banking   Uttar Pradesh  Mathura
# 3                             20.76             UPI     Maharashtra   Mumbai
# 4                              5.05             COD  Madhya Pradesh   Indore
#
# [5 rows x 21 columns]

# %%
# Brand wise Screen Size Distribution
brand_wise_screen_size = sql_data.groupby(["brand","screen_size"]).size().reset_index(name="count")
brand_wise_screen_size
# Out:
#       brand screen_size  count
# 0     Apple      Medium     35
# 1     Apple       Small     17
# 2     Apple  Very Small      4
# 3      Poco       Large     54
# 4      Poco      Medium      2
# 5    Realme       Large     82
# 6    Realme      Medium     56
# 7   Samsung       Large     82
# 8   Samsung      Medium     26
# 9   Samsung       Small      7
# 10  Samsung  Very Large      4
# 11   Xiaomi       Large     24
# 12   Xiaomi      Medium     27
# 13   Xiaomi       Small     10

# %%
# Bar Plot
plt.figure(figsize=(10,5))
barplot=sns.barplot(data=brand_wise_screen_size,x="brand",y="count",hue="screen_size",palette="husl")
for container in barplot.containers:
    barplot.bar_label(container)                  # values at edge of each bar(for loop con each containers in bar plot)
plt.title("Brand wise Screen Size Distribution")
plt.xlabel("Brand")
plt.ylabel("Count")
barplot.set_ylim(0, 100)    # min and max limit od Y axis
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# **Observations**:
#
# - We have **5 Brand Groups** with in the data set => **Apple** , **Poco** , **Realme** , **Samsung** , **Xiaomi** .
# - We have **5 Screen Size Groups** with in the data set => **Very Small** , **Small** , **Medium** , **Large** , **Very Large** .
# - From **DataFrame Analysis** we conclude that **Apple** has only **Very Small Screen Size** (**4**) .
# - From **DataFrame Analysis** we also conclude that **Apple** has maximum **Small Screen Size** (**17**) .
# - From **DataFrame Analysis** we also conclude that **Realme** has maximum **Medium Screen Size** (**56**) .
# - From **DataFrame Analysis** we also conclude that **Realme** and **Samsung**  both have maximum **Large Screen Size** (**82**) .
# - From **DataFrame Analysis** we also conclude that **Samsung** has only **Very Large Screen Size** (**4**) .
# - From **DataFrame Analysis** we also conclude that **Large Screen Size** has maximum number of sales [82+82=164] (**164**) .
# - From **DataFrame Analysis** we also conclude that **Very Small Screen Size** and **Very Large Screen Size** have minimunm number of sales [4+4=8] (**8**) .

# %% [markdown]
# ### Q.7 Brand wise ROM Distribution

# %%
# Data Set of Flipkart Mobile
sql_data.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  ...  ratings  \
# 0           4.7                1                 1  ...      4.5
# 1           5.4                2                 1  ...      4.5
# 2           4.7                1                 1  ...      4.5
# 3           6.1                1                 1  ...      4.6
# 4           6.1                2                 1  ...      4.6
#
#    num_of_ratings  sale_price_before_discount  discount_percent  \
# 0           38645                       32999              17.0
# 1             244                       57149               4.0
# 2           38645                       32999              17.0
# 3            5366                       42999              10.0
# 4             745                       69149               2.0
#
#    discount_amount  total_sales_before_discount_crore  \
# 0          5609.83                             127.52
# 1          2285.96                               1.39
# 2          5609.83                             127.52
# 3          4299.90                              23.07
# 4          1382.98                               5.15
#
#    total_sales_after_discount_crore  payment_method           state     city
# 0                            105.84             UPI   Uttar Pradesh  Mathura
# 1                              1.33     Credit Card           Delhi    Delhi
# 2                            105.84     Net Banking   Uttar Pradesh  Mathura
# 3                             20.76             UPI     Maharashtra   Mumbai
# 4                              5.05             COD  Madhya Pradesh   Indore
#
# [5 rows x 21 columns]

# %%
# Brand wise ROM Distribution
brand_wise_ROM = sql_data.groupby(["brand","ROM"]).size().reset_index(name="count")
brand_wise_ROM
# Out:
#       brand  ROM  count
# 0     Apple   32      1
# 1     Apple   64     23
# 2     Apple  128     20
# 3     Apple  256     12
# 4      Poco   32      3
# 5      Poco   64     22
# 6      Poco  128     28
# 7      Poco  256      3
# 8    Realme   16      2
# 9    Realme   32     22
# 10   Realme   64     39
# 11   Realme  128     64
# 12   Realme  256     11
# 13  Samsung    8      2
# 14  Samsung   16      2
# 15  Samsung   32     18
# 16  Samsung   64     27
# 17  Samsung  128     58
# 18  Samsung  256     11
# 19  Samsung  512      1
# 20   Xiaomi   16      1
# 21   Xiaomi   32     10
# 22   Xiaomi   64     27
# 23   Xiaomi  128     22
# 24   Xiaomi  256      1

# %%
# Bar Plot
plt.figure(figsize=(10,5))
barplot=sns.barplot(data=brand_wise_ROM,x="ROM",y="count",hue="brand",palette="Set1")
for container in barplot.containers:
    barplot.bar_label(container)          # values at edgeof each bar(for loop con each containers in bar plot)
plt.title("Brand wise ROM Distribution")
plt.xlabel("ROM in GB")
plt.ylabel("Count")
barplot.set_ylim(0, 80) # min and max limit od Y axis
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# **Observations**:
#
# - We have **5 Brand Groups** with in the data set => **Apple** , **Poco** , **Realme** , **Samsung** , **Xiaomi** .
# - We have **7 ROM Groups** with in the data set => **8 GB** , **16 GB** , **32 GB** , **64 GB** , **128 GB** , **256 GB** , **512 GB** .
# - From **DataFrame Analysis** we conclude that **Samsung** has only **8 GB ROM** (**2**) .
# - From **DataFrame Analysis** we also conclude that **Realme** and **Samsung** both have maximum **16 GB ROM** (**2**) .
# - From **DataFrame Analysis** we also conclude that **Realme** has maximum **32 GB ROM** (**22**) .
# - From **DataFrame Analysis** we also conclude that **Realme** has maximum **64 GB ROM** (**39**) .
# - From **DataFrame Analysis** we also conclude that **Realme** has maximum **128 GB ROM** (**64**) .
# - From **DataFrame Analysis** we also conclude that **Apple** has maximum **256 GB ROM** (**12**) .
# - From **DataFrame Analysis** we also conclude that **Samsung** has only **512 GB ROM** (**1**) .
# - From **DataFrame Analysis** we also conclude that **128 GB ROM** has maximum number of sales [20+28+64+58+22=192] (**192**) .
# - From **DataFrame Analysis** we also conclude that **512 GB ROM** has minimunm number of sales (**1**) .

# %% [markdown]
# ### Q.8 Brand wise RAM Distribution

# %%
# Data Set of Flipkart Mobile
sql_data.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  ...  ratings  \
# 0           4.7                1                 1  ...      4.5
# 1           5.4                2                 1  ...      4.5
# 2           4.7                1                 1  ...      4.5
# 3           6.1                1                 1  ...      4.6
# 4           6.1                2                 1  ...      4.6
#
#    num_of_ratings  sale_price_before_discount  discount_percent  \
# 0           38645                       32999              17.0
# 1             244                       57149               4.0
# 2           38645                       32999              17.0
# 3            5366                       42999              10.0
# 4             745                       69149               2.0
#
#    discount_amount  total_sales_before_discount_crore  \
# 0          5609.83                             127.52
# 1          2285.96                               1.39
# 2          5609.83                             127.52
# 3          4299.90                              23.07
# 4          1382.98                               5.15
#
#    total_sales_after_discount_crore  payment_method           state     city
# 0                            105.84             UPI   Uttar Pradesh  Mathura
# 1                              1.33     Credit Card           Delhi    Delhi
# 2                            105.84     Net Banking   Uttar Pradesh  Mathura
# 3                             20.76             UPI     Maharashtra   Mumbai
# 4                              5.05             COD  Madhya Pradesh   Indore
#
# [5 rows x 21 columns]

# %%
# Brand wise RAM Distribution
brand_wise_RAM = sql_data.groupby(["brand","RAM"]).size().reset_index(name="count")
brand_wise_RAM
# Out:
#       brand  RAM  count
# 0     Apple    2      5
# 1     Apple    3     18
# 2     Apple    4     33
# 3      Poco    3      3
# 4      Poco    4     13
# 5      Poco    6     30
# 6      Poco    8     10
# 7    Realme    2      9
# 8    Realme    3     15
# 9    Realme    4     37
# 10   Realme    6     33
# 11   Realme    8     38
# 12   Realme   12      6
# 13  Samsung    1      2
# 14  Samsung    2      5
# 15  Samsung    3     15
# 16  Samsung    4     28
# 17  Samsung    6     31
# 18  Samsung    8     32
# 19  Samsung   12      6
# 20   Xiaomi    2      2
# 21   Xiaomi    3      9
# 22   Xiaomi    4     22
# 23   Xiaomi    6     20
# 24   Xiaomi    8      8

# %%
# Bar Plot
plt.figure(figsize=(10,5))
barplot=sns.barplot(data=brand_wise_RAM, x="RAM",y="count",hue="brand",palette="Set1")
for container in barplot.containers:
    barplot.bar_label(container)    # values at edge of each bar(for loop con each containers in bar plot)
plt.title("Brand wise RAM Distribution")
plt.xlabel("RAM in GB")
plt.ylabel("Count")
barplot.set_ylim(0, 40)   # min and max limit od Y axis
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# **Observations**:
#
# - We have **5 Brand Groups** with in the data set => **Apple** , **Poco** , **Realme** , **Samsung** , **Xiaomi** .
# - We have **7 RAM Groups** with in the data set => **1 GB** , **2 GB** , **3 GB** , **4 GB** , **6 GB** , **8 GB** , **12 GB** .
# - From **DataFrame Analysis** we conclude that **Samsung** has only **1 GB RAM** (**2**) .
# - From **DataFrame Analysis** we also conclude that **Realme** has maximum **2 GB RAM** (**9**) .
# - From **DataFrame Analysis** we also conclude that **Apple** has maximum **3 GB RAM**(**18**) .
# - From **DataFrame Analysis** we also conclude that **Realme** has maximum **4 GB RAM** (**37**) .
# - From **DataFrame Analysis** we also conclude that **Realme** has maximum **6 GB RAM** (**33**) .
# - From **DataFrame Analysis** we also conclude that **Realme** has maximum **8 GB RAM** (**38**) .
# - From **DataFrame Analysis** we also conclude that **Realme** and **Samsung** both have maximum **12 GB RAM** (**6**) .
# - From **DataFrame Analysis** we also conclude that **4 GB RAM** has maximum number of sales [33+13+37+28+22=192] (**133**) .
# - From **DataFrame Analysis** we also conclude that **1 GB RAM** has minimunm number of sales (**2**) .

# %% [markdown]
# ### Q.9 Brand wise Rating Factor(RF) distribution

# %%
# Data Set of Flipkart Mobile
sql_data.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  ...  ratings  \
# 0           4.7                1                 1  ...      4.5
# 1           5.4                2                 1  ...      4.5
# 2           4.7                1                 1  ...      4.5
# 3           6.1                1                 1  ...      4.6
# 4           6.1                2                 1  ...      4.6
#
#    num_of_ratings  sale_price_before_discount  discount_percent  \
# 0           38645                       32999              17.0
# 1             244                       57149               4.0
# 2           38645                       32999              17.0
# 3            5366                       42999              10.0
# 4             745                       69149               2.0
#
#    discount_amount  total_sales_before_discount_crore  \
# 0          5609.83                             127.52
# 1          2285.96                               1.39
# 2          5609.83                             127.52
# 3          4299.90                              23.07
# 4          1382.98                               5.15
#
#    total_sales_after_discount_crore  payment_method           state     city
# 0                            105.84             UPI   Uttar Pradesh  Mathura
# 1                              1.33     Credit Card           Delhi    Delhi
# 2                            105.84     Net Banking   Uttar Pradesh  Mathura
# 3                             20.76             UPI     Maharashtra   Mumbai
# 4                              5.05             COD  Madhya Pradesh   Indore
#
# [5 rows x 21 columns]

# %%
# new column insertion is Rating Factor(RF) and its distribution in brandwise.[logic : ((sql_data["ratings"]/5)*sql_data["num_of_ratings"])/1000 ]
sql_data["rating_factor"]=((sql_data["ratings"]/5)*sql_data["num_of_ratings"])/1000
sql_data.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  ...  num_of_ratings  \
# 0           4.7                1                 1  ...           38645
# 1           5.4                2                 1  ...             244
# 2           4.7                1                 1  ...           38645
# 3           6.1                1                 1  ...            5366
# 4           6.1                2                 1  ...             745
#
#    sale_price_before_discount  discount_percent  discount_amount  \
# 0                       32999              17.0          5609.83
# 1                       57149               4.0          2285.96
# 2                       32999              17.0          5609.83
# 3                       42999              10.0          4299.90
# 4                       69149               2.0          1382.98
#
#    total_sales_before_discount_crore  total_sales_after_discount_crore  \
# 0                             127.52                            105.84
# 1                               1.39                              1.33
# 2                             127.52                            105.84
# 3                              23.07                             20.76
# 4                               5.15                              5.05
#
#    payment_method           state     city rating_factor
# 0             UPI   Uttar Pradesh  Mathura      34.78050
# 1     Credit Card           Delhi    Delhi       0.21960
# 2     Net Banking   Uttar Pradesh  Mathura      34.78050
# 3             UPI     Maharashtra   Mumbai       4.93672
# 4             COD  Madhya Pradesh   Indore       0.68540
#
# [5 rows x 22 columns]

# %%
# rearrange the DataFrame in proper maner in column wise
rearrange_data_frame =['brand', 'model', 'base_color', 'processor', 'screen_size', 'ROM', 'RAM', 'display_size',  'num_rear_camera', 'num_front_camera', 'battery_capacity', 'ratings',  'num_of_ratings', 'rating_factor', 'sale_price_before_discount', 'discount_percent', 'discount_amount', 'total_sales_before_discount_crore', 'total_sales_after_discount_crore', 'payment_method', 'state', 'city']  
sql_data=sql_data[rearrange_data_frame]
sql_data.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  ...  num_of_ratings  \
# 0           4.7                1                 1  ...           38645
# 1           5.4                2                 1  ...             244
# 2           4.7                1                 1  ...           38645
# 3           6.1                1                 1  ...            5366
# 4           6.1                2                 1  ...             745
#
#    rating_factor  sale_price_before_discount  discount_percent  \
# 0       34.78050                       32999              17.0
# 1        0.21960                       57149               4.0
# 2       34.78050                       32999              17.0
# 3        4.93672                       42999              10.0
# 4        0.68540                       69149               2.0
#
#    discount_amount  total_sales_before_discount_crore  \
# 0          5609.83                             127.52
# 1          2285.96                               1.39
# 2          5609.83                             127.52
# 3          4299.90                              23.07
# 4          1382.98                               5.15
#
#    total_sales_after_discount_crore  payment_method           state     city
# 0                            105.84             UPI   Uttar Pradesh  Mathura
# 1                              1.33     Credit Card           Delhi    Delhi
# 2                            105.84     Net Banking   Uttar Pradesh  Mathura
# 3                             20.76             UPI     Maharashtra   Mumbai
# 4                              5.05             COD  Madhya Pradesh   Indore
#
# [5 rows x 22 columns]

# %%
# Brand wise Rating Factor Distribution
brand_wise_rating_factor=sql_data.groupby("brand")["rating_factor"].sum().round(2).reset_index()
brand_wise_rating_factor
# Out:
#      brand  rating_factor
# 0    Apple         245.26
# 1     Poco        1578.06
# 2   Realme        3531.23
# 3  Samsung         593.53
# 4   Xiaomi        2830.49

# %%
# Bar Plot
plt.figure(figsize=(10,5))
barplot=sns.barplot(data=brand_wise_rating_factor, x="brand", y="rating_factor", palette="Set1", hue="brand")
for container in barplot.containers:
    barplot.bar_label(container)      # values at edge of each bar(for loop con each containers in bar plot)
plt.title("Brand wise Rating Factor(RF) Distribution")
plt.xlabel("Brand")
plt.ylabel("Rating Facor(RF)")
barplot.set_ylim(0, 4000)   # min and max limit od Y axis
plt.show()

# %% [markdown]
# **Observations**:
#
# - We have **5 Brand Groups** with in the data set => **Apple** , **Poco** , **Realme** , **Samsung** , **Xiaomi** .
# - From **DataFrame Analysis** we conclude that **Realme** has maximum **Rating Factor** (**3531.23**) .
# - From **DataFrame Analysis** we also conclude that **Apple** has minimum **Rating Factor** (**245.26**) .

# %% [markdown]
# ### Q.10 Brand wise unit of sales distribution

# %%
# Data Set of Flipkart Mobile
sql_data.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  ...  num_of_ratings  \
# 0           4.7                1                 1  ...           38645
# 1           5.4                2                 1  ...             244
# 2           4.7                1                 1  ...           38645
# 3           6.1                1                 1  ...            5366
# 4           6.1                2                 1  ...             745
#
#    rating_factor  sale_price_before_discount  discount_percent  \
# 0       34.78050                       32999              17.0
# 1        0.21960                       57149               4.0
# 2       34.78050                       32999              17.0
# 3        4.93672                       42999              10.0
# 4        0.68540                       69149               2.0
#
#    discount_amount  total_sales_before_discount_crore  \
# 0          5609.83                             127.52
# 1          2285.96                               1.39
# 2          5609.83                             127.52
# 3          4299.90                              23.07
# 4          1382.98                               5.15
#
#    total_sales_after_discount_crore  payment_method           state     city
# 0                            105.84             UPI   Uttar Pradesh  Mathura
# 1                              1.33     Credit Card           Delhi    Delhi
# 2                            105.84     Net Banking   Uttar Pradesh  Mathura
# 3                             20.76             UPI     Maharashtra   Mumbai
# 4                              5.05             COD  Madhya Pradesh   Indore
#
# [5 rows x 22 columns]

# %%
# new column insertion is Unit of Sales and its distribution in brandwise.[logic : ((sql_data["ratings"]/5)*sql_data["num_of_ratings"])/1000 ]
sql_data["unit_of_sales"]=round(((sql_data["total_sales_before_discount_crore"])*10000000)/sql_data["sale_price_before_discount"],0)
sql_data.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  ...  rating_factor  \
# 0           4.7                1                 1  ...       34.78050
# 1           5.4                2                 1  ...        0.21960
# 2           4.7                1                 1  ...       34.78050
# 3           6.1                1                 1  ...        4.93672
# 4           6.1                2                 1  ...        0.68540
#
#    sale_price_before_discount  discount_percent  discount_amount  \
# 0                       32999              17.0          5609.83
# 1                       57149               4.0          2285.96
# 2                       32999              17.0          5609.83
# 3                       42999              10.0          4299.90
# 4                       69149               2.0          1382.98
#
#    total_sales_before_discount_crore  total_sales_after_discount_crore  \
# 0                             127.52                            105.84
# 1                               1.39                              1.33
# 2                             127.52                            105.84
# 3                              23.07                             20.76
# 4                               5.15                              5.05
#
#    payment_method           state     city unit_of_sales
# 0             UPI   Uttar Pradesh  Mathura       38644.0
# 1     Credit Card           Delhi    Delhi         243.0
# 2     Net Banking   Uttar Pradesh  Mathura       38644.0
# 3             UPI     Maharashtra   Mumbai        5365.0
# 4             COD  Madhya Pradesh   Indore         745.0
#
# [5 rows x 23 columns]

# %%
# Brand wise Unit of Sales Distribution in Lakh
brand_wise_unit_of_sales_in_lakh=((sql_data.groupby("brand")["unit_of_sales"].sum())/100000).reset_index()
brand_wise_unit_of_sales_in_lakh
# Out:
#      brand  unit_of_sales
# 0    Apple        2.70083
# 1     Poco       18.07971
# 2   Realme       40.33327
# 3  Samsung        8.31173
# 4   Xiaomi       31.91593

# %%
# Bar Plot
plt.figure(figsize=(10,5))
barplot=sns.barplot(data=brand_wise_unit_of_sales_in_lakh, x="brand",y="unit_of_sales",palette="Set1",hue="brand")
for container in barplot.containers:
    barplot.bar_label(container) # values at edge of each bar(for loop con each containers in bar plot)
plt.title("Brand wise Unit Sales Distribution")
plt.xlabel("Brand")
plt.ylabel("Unit Sales in Lakh")
barplot.set_ylim(0, 50) # min and max limit od Y axis
plt.show()

# %% [markdown]
# **Observations**:
#
# - We have **5 Brand Groups** with in the data set => **Apple** , **Poco** , **Realme** , **Samsung** , **Xiaomi** .
# - From **DataFrame Analysis** we conclude that **Realme** has maximum **Unit of Sales** (**40.33327 lakh**) .
# - From **DataFrame Analysis** we also conclude that **Apple** has minimum **Unit of Sales** (**2.70083 lakh**) .

# %% [markdown]
# ### Q.11 Brand wise Display Size Distribution

# %%
# Data Set of Flipkart Mobile
sql_data.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  ...  rating_factor  \
# 0           4.7                1                 1  ...       34.78050
# 1           5.4                2                 1  ...        0.21960
# 2           4.7                1                 1  ...       34.78050
# 3           6.1                1                 1  ...        4.93672
# 4           6.1                2                 1  ...        0.68540
#
#    sale_price_before_discount  discount_percent  discount_amount  \
# 0                       32999              17.0          5609.83
# 1                       57149               4.0          2285.96
# 2                       32999              17.0          5609.83
# 3                       42999              10.0          4299.90
# 4                       69149               2.0          1382.98
#
#    total_sales_before_discount_crore  total_sales_after_discount_crore  \
# 0                             127.52                            105.84
# 1                               1.39                              1.33
# 2                             127.52                            105.84
# 3                              23.07                             20.76
# 4                               5.15                              5.05
#
#    payment_method           state     city unit_of_sales
# 0             UPI   Uttar Pradesh  Mathura       38644.0
# 1     Credit Card           Delhi    Delhi         243.0
# 2     Net Banking   Uttar Pradesh  Mathura       38644.0
# 3             UPI     Maharashtra   Mumbai        5365.0
# 4             COD  Madhya Pradesh   Indore         745.0
#
# [5 rows x 23 columns]

# %%
# Brand wise "Display Size" and its "Unit of sales" and "Unit of sales in  thousand" Distribution
display_size_wise_mobile_count = sql_data.groupby(["brand","display_size"])["unit_of_sales"].sum().reset_index()
display_size_wise_mobile_count["unit_of_sales_in _thousand"]=(display_size_wise_mobile_count["unit_of_sales"]/1000)
display_size_wise_mobile_count
# Out:
#       brand  display_size  unit_of_sales  unit_of_sales_in _thousand
# 0     Apple           4.7       127212.0                     127.212
# 1     Apple           5.4         3904.0                       3.904
# 2     Apple           5.5        29714.0                      29.714
# 3     Apple           6.1       109253.0                     109.253
# 4      Poco           6.2       136024.0                     136.024
# 5      Poco           6.5       968564.0                     968.564
# 6      Poco           6.7       703383.0                     703.383
# 7    Realme           6.1       716919.0                     716.919
# 8    Realme           6.2       189762.0                     189.762
# 9    Realme           6.3       109401.0                     109.401
# 10   Realme           6.4       219236.0                     219.236
# 11   Realme           6.5      2787835.0                    2787.835
# 12   Realme           6.6        10174.0                      10.174
# 13  Samsung           5.2         4688.0                       4.688
# 14  Samsung           5.5        77831.0                      77.831
# 15  Samsung           5.6        42276.0                      42.276
# 16  Samsung           5.7        20484.0                      20.484
# 17  Samsung           6.0        12902.0                      12.902
# 18  Samsung           6.1         1910.0                       1.910
# 19  Samsung           6.2        13250.0                      13.250
# 20  Samsung           6.4       477500.0                     477.500
# 21  Samsung           6.5       121732.0                     121.732
# 22  Samsung           6.6          292.0                       0.292
# 23  Samsung           6.7        58057.0                      58.057
# 24  Samsung           6.9          220.0                       0.220
# 25  Samsung           7.6           31.0                       0.031
# 26   Xiaomi           5.5      1168988.0                    1168.988
# 27   Xiaomi           5.7         4267.0                       4.267
# 28   Xiaomi           5.8        10959.0                      10.959
# 29   Xiaomi           6.0       736901.0                     736.901
# 30   Xiaomi           6.1        37368.0                      37.368
# 31   Xiaomi           6.2        16316.0                      16.316
# 32   Xiaomi           6.3      1107654.0                    1107.654
# 33   Xiaomi           6.4        50771.0                      50.771
# 34   Xiaomi           6.5        35409.0                      35.409
# 35   Xiaomi           6.7        22960.0                      22.960

# %%
# Bar Plot
plt.figure(figsize=(10,5))
sns.barplot(data=display_size_wise_mobile_count, x="display_size",y="unit_of_sales_in _thousand",hue="brand",palette="Set1")
plt.title("Brand wise Display Size Distribution")
plt.xlabel("Display Size in Inch")
plt.ylabel("Unit of Sales in Thousand")
plt.legend(loc="upper right")
plt.show()

# %%
# "Display Size" wise "Unit of sales in thousand" Distribution
display_size_wise_mobile_count.groupby("display_size")["unit_of_sales_in _thousand"].sum().reset_index()
# Out:
#     display_size  unit_of_sales_in _thousand
# 0            4.7                     127.212
# 1            5.2                       4.688
# 2            5.4                       3.904
# 3            5.5                    1276.533
# 4            5.6                      42.276
# 5            5.7                      24.751
# 6            5.8                      10.959
# 7            6.0                     749.803
# 8            6.1                     865.450
# 9            6.2                     355.352
# 10           6.3                    1217.055
# 11           6.4                     747.507
# 12           6.5                    3913.540
# 13           6.6                      10.466
# 14           6.7                     784.400
# 15           6.9                       0.220
# 16           7.6                       0.031

# %% [markdown]
# **Observations**:
#
# - We have **5 Brand Groups** with in the data set => **Apple** , **Poco** , **Realme** , **Samsung** , **Xiaomi** .
# - We have **17 Display Size(Inch) Groups** with in the data set => **4.7** , **5.2** , **5.4** , **5.5** , **5.6** , **5.7** , **5.8** , **6.0** , **6.1** , **6.2** , **6.3** , **6.4** , **6.5** , **6.6** , **6.7** , **6.9** , **7.6** .
# - From **DataFrame Analysis** we conclude that **6.5 Inch Display Size** has maximum **Sales** (**3913.540 Thousand = 3913540**) .
# - From **DataFrame Analysis** we also conclude that **7.6 Inch Display Size** has minimum **Unit of Sales** (**0.031 Thousand = 31**) .
# - From **DataFrame Analysis** we conclude that **6.5 Inch Display Size** has maximum **Sales** and their **Realme** has maximum (**2787.835 Thousand = 2787835**) .
# - From **DataFrame Analysis** we conclude that **6.5 Inch Display Size** has maximum **Sales** and their **Xiaomi** has minimum (**35.409 Thousand = 35409**) .

# %% [markdown]
# ### Heatmap Pearson Correlation of Sales and Discount

# %%
# Data Set of Flipkart Mobile
sql_data.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  ...  rating_factor  \
# 0           4.7                1                 1  ...       34.78050
# 1           5.4                2                 1  ...        0.21960
# 2           4.7                1                 1  ...       34.78050
# 3           6.1                1                 1  ...        4.93672
# 4           6.1                2                 1  ...        0.68540
#
#    sale_price_before_discount  discount_percent  discount_amount  \
# 0                       32999              17.0          5609.83
# 1                       57149               4.0          2285.96
# 2                       32999              17.0          5609.83
# 3                       42999              10.0          4299.90
# 4                       69149               2.0          1382.98
#
#    total_sales_before_discount_crore  total_sales_after_discount_crore  \
# 0                             127.52                            105.84
# 1                               1.39                              1.33
# 2                             127.52                            105.84
# 3                              23.07                             20.76
# 4                               5.15                              5.05
#
#    payment_method           state     city unit_of_sales
# 0             UPI   Uttar Pradesh  Mathura       38644.0
# 1     Credit Card           Delhi    Delhi         243.0
# 2     Net Banking   Uttar Pradesh  Mathura       38644.0
# 3             UPI     Maharashtra   Mumbai        5365.0
# 4             COD  Madhya Pradesh   Indore         745.0
#
# [5 rows x 23 columns]

# %%
#heatmap correlation
plt.figure(figsize = (12,6))
sns.heatmap(sql_data[["sale_price_before_discount","discount_amount","total_sales_before_discount_crore","total_sales_after_discount_crore"]].corr(),annot=True)
plt.title("Pearson Correlation")
plt.show()

# %% [markdown]
# ### Brand Wise Sales Price After Discount (Box Plot)

# %%
# Data Set of Flipkart Mobile
sql_data.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  ...  rating_factor  \
# 0           4.7                1                 1  ...       34.78050
# 1           5.4                2                 1  ...        0.21960
# 2           4.7                1                 1  ...       34.78050
# 3           6.1                1                 1  ...        4.93672
# 4           6.1                2                 1  ...        0.68540
#
#    sale_price_before_discount  discount_percent  discount_amount  \
# 0                       32999              17.0          5609.83
# 1                       57149               4.0          2285.96
# 2                       32999              17.0          5609.83
# 3                       42999              10.0          4299.90
# 4                       69149               2.0          1382.98
#
#    total_sales_before_discount_crore  total_sales_after_discount_crore  \
# 0                             127.52                            105.84
# 1                               1.39                              1.33
# 2                             127.52                            105.84
# 3                              23.07                             20.76
# 4                               5.15                              5.05
#
#    payment_method           state     city unit_of_sales
# 0             UPI   Uttar Pradesh  Mathura       38644.0
# 1     Credit Card           Delhi    Delhi         243.0
# 2     Net Banking   Uttar Pradesh  Mathura       38644.0
# 3             UPI     Maharashtra   Mumbai        5365.0
# 4             COD  Madhya Pradesh   Indore         745.0
#
# [5 rows x 23 columns]

# %%
# new column insertion is sale_price_after_discount and its distribution in brandwise.[logic : ((sql_data["ratings"]/5)*sql_data["num_of_ratings"])/1000 ]
sql_data["sale_price_after_discount"]=sql_data["sale_price_before_discount"]-sql_data["discount_amount"]
sql_data.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  ...  \
# 0           4.7                1                 1  ...
# 1           5.4                2                 1  ...
# 2           4.7                1                 1  ...
# 3           6.1                1                 1  ...
# 4           6.1                2                 1  ...
#
#    sale_price_before_discount  discount_percent  discount_amount  \
# 0                       32999              17.0          5609.83
# 1                       57149               4.0          2285.96
# 2                       32999              17.0          5609.83
# 3                       42999              10.0          4299.90
# 4                       69149               2.0          1382.98
#
#    total_sales_before_discount_crore  total_sales_after_discount_crore  \
# 0                             127.52                            105.84
# 1                               1.39                              1.33
# 2                             127.52                            105.84
# 3                              23.07                             20.76
# 4                               5.15                              5.05
#
#    payment_method           state     city  unit_of_sales  \
# 0             UPI   Uttar Pradesh  Mathura        38644.0
# 1     Credit Card           Delhi    Delhi          243.0
# 2     Net Banking   Uttar Pradesh  Mathura        38644.0
# 3             UPI     Maharashtra   Mumbai         5365.0
# 4             COD  Madhya Pradesh   Indore          745.0
#
#   sale_price_after_discount
# 0                  27389.17
# 1                  54863.04
# 2                  27389.17
# 3                  38699.10
# 4                  67766.02
#
# [5 rows x 24 columns]

# %%
# rearrange the DataFrame in proper maner in column wise
rearrage_data_frame =['brand', 'model', 'base_color', 'processor', 'screen_size', 'ROM', 'RAM', 'display_size',  'num_rear_camera', 'num_front_camera', 'battery_capacity', 'ratings',  'num_of_ratings', 'rating_factor', 'sale_price_before_discount', 'discount_percent', 'discount_amount', 'sale_price_after_discount', 'total_sales_before_discount_crore', 'total_sales_after_discount_crore', 'unit_of_sales', 'payment_method', 'state', 'city']  
sql_data=sql_data[rearrage_data_frame]
sql_data.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  ...  \
# 0           4.7                1                 1  ...
# 1           5.4                2                 1  ...
# 2           4.7                1                 1  ...
# 3           6.1                1                 1  ...
# 4           6.1                2                 1  ...
#
#    sale_price_before_discount  discount_percent  discount_amount  \
# 0                       32999              17.0          5609.83
# 1                       57149               4.0          2285.96
# 2                       32999              17.0          5609.83
# 3                       42999              10.0          4299.90
# 4                       69149               2.0          1382.98
#
#    sale_price_after_discount  total_sales_before_discount_crore  \
# 0                   27389.17                             127.52
# 1                   54863.04                               1.39
# 2                   27389.17                             127.52
# 3                   38699.10                              23.07
# 4                   67766.02                               5.15
#
#    total_sales_after_discount_crore  unit_of_sales  payment_method  \
# 0                            105.84        38644.0             UPI
# 1                              1.33          243.0     Credit Card
# 2                            105.84        38644.0     Net Banking
# 3                             20.76         5365.0             UPI
# 4                              5.05          745.0             COD
#
#             state     city
# 0   Uttar Pradesh  Mathura
# 1           Delhi    Delhi
# 2   Uttar Pradesh  Mathura
# 3     Maharashtra   Mumbai
# 4  Madhya Pradesh   Indore
#
# [5 rows x 24 columns]

# %%
# box plot
plt.figure(figsize = (10,6))
sns.boxplot(data = sql_data, x = 'brand',y = 'sale_price_after_discount' )
plt.title("Brand Wise Sales Price After Discount (Box Plot)")
plt.show()

# %% [markdown]
# **Observations**:
#
# - We have **5 Brand Groups** with in the data set => **Apple** , **Poco** , **Realme** , **Samsung** , **Xiaomi** .
# - From **DataFrame Analysis** we conclude that **Samsung** has maximum Number of **Mobiles** with higher **Price Tag** (**9**) [ 9 Out of Purchase Range].
# - From **DataFrame Analysis** we conclude that **Apple** has minimum Number of **Mobiles** with higher **Price Tag** (**0**) [ zero (0) Out of Purchase Range].

# %% [markdown]
# ### Histogram Diagram of Flipkart Sales Data of 2023

# %%
# histogram diagram
sql_data.hist(figsize = (15,10))
plt.show()

# %% [markdown]
# ### Ratings Category Wise Mobile Count Distribution

# %%
# Data Set of Flipkart Mobile
sql_data.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  ...  \
# 0           4.7                1                 1  ...
# 1           5.4                2                 1  ...
# 2           4.7                1                 1  ...
# 3           6.1                1                 1  ...
# 4           6.1                2                 1  ...
#
#    sale_price_before_discount  discount_percent  discount_amount  \
# 0                       32999              17.0          5609.83
# 1                       57149               4.0          2285.96
# 2                       32999              17.0          5609.83
# 3                       42999              10.0          4299.90
# 4                       69149               2.0          1382.98
#
#    sale_price_after_discount  total_sales_before_discount_crore  \
# 0                   27389.17                             127.52
# 1                   54863.04                               1.39
# 2                   27389.17                             127.52
# 3                   38699.10                              23.07
# 4                   67766.02                               5.15
#
#    total_sales_after_discount_crore  unit_of_sales  payment_method  \
# 0                            105.84        38644.0             UPI
# 1                              1.33          243.0     Credit Card
# 2                            105.84        38644.0     Net Banking
# 3                             20.76         5365.0             UPI
# 4                              5.05          745.0             COD
#
#             state     city
# 0   Uttar Pradesh  Mathura
# 1           Delhi    Delhi
# 2   Uttar Pradesh  Mathura
# 3     Maharashtra   Mumbai
# 4  Madhya Pradesh   Indore
#
# [5 rows x 24 columns]

# %%
# Rating wise Count
sql_data["ratings"].value_counts().reset_index()
# Out:
#    ratings  count
# 0      4.3    178
# 1      4.4     79
# 2      4.5     55
# 3      4.2     54
# 4      4.6     37
# 5      4.0     10
# 6      4.1      8
# 7      3.9      3
# 8      3.8      1
# 9      3.0      1

# %%
# ratings_category --> >=4.6 --> Outstanding, >=4.4 --> Very Good, >=4.2 --> Good, >=4.0 --> Satisfactory, <=4.0 --> Bad
def ratings_category(x):
    if x>=4.6:
        return "Outstanding"
    elif x>=4.4:
        return "Very Good"
    elif x>=4.2:
        return "Good"
    elif x>=4.0:
        return "Satisfactory"
    else:
        return "Bad"

sql_data["ratings_category"]=sql_data["ratings"].apply(ratings_category)
sql_data.head(5)
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  ...  discount_percent  \
# 0           4.7                1                 1  ...              17.0
# 1           5.4                2                 1  ...               4.0
# 2           4.7                1                 1  ...              17.0
# 3           6.1                1                 1  ...              10.0
# 4           6.1                2                 1  ...               2.0
#
#    discount_amount  sale_price_after_discount  \
# 0          5609.83                   27389.17
# 1          2285.96                   54863.04
# 2          5609.83                   27389.17
# 3          4299.90                   38699.10
# 4          1382.98                   67766.02
#
#    total_sales_before_discount_crore  total_sales_after_discount_crore  \
# 0                             127.52                            105.84
# 1                               1.39                              1.33
# 2                             127.52                            105.84
# 3                              23.07                             20.76
# 4                               5.15                              5.05
#
#    unit_of_sales  payment_method           state     city  ratings_category
# 0        38644.0             UPI   Uttar Pradesh  Mathura         Very Good
# 1          243.0     Credit Card           Delhi    Delhi         Very Good
# 2        38644.0     Net Banking   Uttar Pradesh  Mathura         Very Good
# 3         5365.0             UPI     Maharashtra   Mumbai       Outstanding
# 4          745.0             COD  Madhya Pradesh   Indore       Outstanding
#
# [5 rows x 25 columns]

# %%
# Brand wise Rating Category Distribution
ratings_category_wise_mobile_count = sql_data.groupby(["brand","ratings_category"]).size().reset_index(name="count")
ratings_category_wise_mobile_count
# Out:
#       brand ratings_category  count
# 0     Apple      Outstanding     35
# 1     Apple        Very Good     21
# 2      Poco             Good     41
# 3      Poco      Outstanding      1
# 4      Poco        Very Good     14
# 5    Realme             Good     78
# 6    Realme     Satisfactory      3
# 7    Realme        Very Good     57
# 8   Samsung              Bad      8
# 9   Samsung             Good     81
# 10  Samsung      Outstanding      1
# 11  Samsung     Satisfactory     13
# 12  Samsung        Very Good     16
# 13   Xiaomi              Bad      1
# 14   Xiaomi             Good     32
# 15   Xiaomi     Satisfactory      2
# 16   Xiaomi        Very Good     26

# %%
# Bar Plot
plt.figure(figsize=(10,5))
barplot=sns.barplot(data=ratings_category_wise_mobile_count, x="brand",y="count",hue="ratings_category",palette="Set1")
for container in barplot.containers:
    barplot.bar_label(container) # values at edge of each bar(for loop con each containers in bar plot)
plt.title("Brand wise Rating Category Distribution")
plt.xlabel("Brand")
plt.ylabel("Count")
barplot.set_ylim(0, 100) # min and max limit od Y axis
plt.show()

# %%
ratings_category_wise_mobile_count
# Out:
#       brand ratings_category  count
# 0     Apple      Outstanding     35
# 1     Apple        Very Good     21
# 2      Poco             Good     41
# 3      Poco      Outstanding      1
# 4      Poco        Very Good     14
# 5    Realme             Good     78
# 6    Realme     Satisfactory      3
# 7    Realme        Very Good     57
# 8   Samsung              Bad      8
# 9   Samsung             Good     81
# 10  Samsung      Outstanding      1
# 11  Samsung     Satisfactory     13
# 12  Samsung        Very Good     16
# 13   Xiaomi              Bad      1
# 14   Xiaomi             Good     32
# 15   Xiaomi     Satisfactory      2
# 16   Xiaomi        Very Good     26

# %%
# Rating Category Wise Sum Distribution
ratings_category_wise_mobile_count.groupby("ratings_category")["count"].sum().reset_index()
# Out:
#   ratings_category  count
# 0              Bad      9
# 1             Good    232
# 2      Outstanding     37
# 3     Satisfactory     18
# 4        Very Good    134

# %% [markdown]
# **Observations**:
#
# - We have **5 Brand Groups** with in the data set => **Apple** , **Poco** , **Realme** , **Samsung** , **Xiaomi** .
# - We have **5 Ratings Category Groups** with in the data set => **Bad** , **Good** , **Outstanding** , **Satisfactory** , **Very Good** .
# - From **DataFrame Analysis** we conclude that **Good Ratings Category** has maximum Number of product (**232**) .
# - From **DataFrame Analysis** we conclude that **Bad Ratings Category** has minimum Number of product  (**9**) .

# %% [markdown]
# ### Payment Method Wise Mobile Unit of Sales Distribution

# %%
sql_data.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  ...  discount_percent  \
# 0           4.7                1                 1  ...              17.0
# 1           5.4                2                 1  ...               4.0
# 2           4.7                1                 1  ...              17.0
# 3           6.1                1                 1  ...              10.0
# 4           6.1                2                 1  ...               2.0
#
#    discount_amount  sale_price_after_discount  \
# 0          5609.83                   27389.17
# 1          2285.96                   54863.04
# 2          5609.83                   27389.17
# 3          4299.90                   38699.10
# 4          1382.98                   67766.02
#
#    total_sales_before_discount_crore  total_sales_after_discount_crore  \
# 0                             127.52                            105.84
# 1                               1.39                              1.33
# 2                             127.52                            105.84
# 3                              23.07                             20.76
# 4                               5.15                              5.05
#
#    unit_of_sales  payment_method           state     city  ratings_category
# 0        38644.0             UPI   Uttar Pradesh  Mathura         Very Good
# 1          243.0     Credit Card           Delhi    Delhi         Very Good
# 2        38644.0     Net Banking   Uttar Pradesh  Mathura         Very Good
# 3         5365.0             UPI     Maharashtra   Mumbai       Outstanding
# 4          745.0             COD  Madhya Pradesh   Indore       Outstanding
#
# [5 rows x 25 columns]

# %%
# Payment Method wise Unit of Sales in Thousand
payment_method_wise_sales=((sql_data.groupby(["payment_method","brand"])["unit_of_sales"].sum())/1000).reset_index()
payment_method_wise_sales
# Out:
#    payment_method    brand  unit_of_sales
# 0             COD    Apple         25.235
# 1             COD     Poco        108.448
# 2             COD   Realme       1101.461
# 3             COD  Samsung        202.229
# 4             COD   Xiaomi       1007.086
# 5     Credit Card    Apple         69.918
# 6     Credit Card     Poco        315.170
# 7     Credit Card   Realme       1069.246
# 8     Credit Card  Samsung        151.942
# 9     Credit Card   Xiaomi        297.787
# 10     Debit Card    Apple         47.532
# 11     Debit Card     Poco        604.700
# 12     Debit Card   Realme        649.525
# 13     Debit Card  Samsung        198.322
# 14     Debit Card   Xiaomi       1157.383
# 15    Net Banking    Apple         59.458
# 16    Net Banking     Poco        394.338
# 17    Net Banking   Realme        630.780
# 18    Net Banking  Samsung        121.068
# 19    Net Banking   Xiaomi        546.777
# 20            UPI    Apple         67.940
# 21            UPI     Poco        385.315
# 22            UPI   Realme        582.315
# 23            UPI  Samsung        157.612
# 24            UPI   Xiaomi        182.560

# %%
# Total unit of sales in Thousand according to payment method:
payment_method_wise_sales_1=((sql_data.groupby("payment_method")["unit_of_sales"].sum())/1000).reset_index()
payment_method_wise_sales_1
# Out:
#   payment_method  unit_of_sales
# 0            COD       2444.459
# 1    Credit Card       1904.063
# 2     Debit Card       2657.462
# 3    Net Banking       1752.421
# 4            UPI       1375.742

# %%
# line Plot
plt.figure(figsize=(20,10))
lineplot=sns.lineplot(data=payment_method_wise_sales, x="payment_method",y="unit_of_sales",hue="brand",marker="o",palette="Set1")
for x, y in zip(payment_method_wise_sales['payment_method'], payment_method_wise_sales['unit_of_sales']):
    lineplot.text(x, y, f'{y:.2f}', ha='center', va='bottom')
plt.title("Brand wise Display Size Distribution")
plt.xlabel("Payment Method")
plt.ylabel("Unit of Sales in Thousand")
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# **Observations**:
#
# - We have **5 Brand Groups** with in the data set => **Apple** , **Poco** , **Realme** , **Samsung** , **Xiaomi** .
# - We have **5 Payment Method Groups** with in the data set => **COD** , **Credit Card** , **Debit Card** , **Net Banking** , **UPI** .
#
# - From **DataFrame Analysis** we conclude that **Apple** has maximum **Unit of Sales in Thousand** (**69.92 Thousand in Credit Card**) & minimum **Unit of Sales in Thousand** (**25.23 Thousand in COD**) .
# - From **DataFrame Analysis** we conclude that **Poco** has maximum **Unit of Sales in Thousand** (**604.70 Thousand in Debit Card**) & minimum **Unit of Sales in Thousand** (**108.45 Thousand in COD**) .
# - From **DataFrame Analysis** we conclude that **Realme** has maximum **Unit of Sales in Thousand** (**1101.46 Thousand in COD**) & minimum **Unit of Sales in Thousand** (**582.32 Thousand in UPI**) .
# - From **DataFrame Analysis** we conclude that **Samsung** has maximum **Unit of Sales in Thousand** (**202.23 Thousand in COD**) & minimum **Unit of Sales in Thousand** (**121.07 Thousand in Net Banking**) .
# - From **DataFrame Analysis** we conclude that **Xiaomi** has maximum **Unit of Sales in Thousand** (**1157.38 Thousand in Debit Card**) & minimum **Unit of Sales in Thousand** (**182.56 Thousand in UPI**) .
# - We conclude that maximum **Unit of Sales in Thousand** (**2657.462 Thousands in COD**) & minimum **Unit of Sales in Thousand** (**1375.742 Thousands in UPI**) .

# %% [markdown]
# ### State Wise Mobile Sales Amount Distribution

# %%
# Data Set of Flipkart Mobile
sql_data.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  ...  discount_percent  \
# 0           4.7                1                 1  ...              17.0
# 1           5.4                2                 1  ...               4.0
# 2           4.7                1                 1  ...              17.0
# 3           6.1                1                 1  ...              10.0
# 4           6.1                2                 1  ...               2.0
#
#    discount_amount  sale_price_after_discount  \
# 0          5609.83                   27389.17
# 1          2285.96                   54863.04
# 2          5609.83                   27389.17
# 3          4299.90                   38699.10
# 4          1382.98                   67766.02
#
#    total_sales_before_discount_crore  total_sales_after_discount_crore  \
# 0                             127.52                            105.84
# 1                               1.39                              1.33
# 2                             127.52                            105.84
# 3                              23.07                             20.76
# 4                               5.15                              5.05
#
#    unit_of_sales  payment_method           state     city  ratings_category
# 0        38644.0             UPI   Uttar Pradesh  Mathura         Very Good
# 1          243.0     Credit Card           Delhi    Delhi         Very Good
# 2        38644.0     Net Banking   Uttar Pradesh  Mathura         Very Good
# 3         5365.0             UPI     Maharashtra   Mumbai       Outstanding
# 4          745.0             COD  Madhya Pradesh   Indore       Outstanding
#
# [5 rows x 25 columns]

# %%
# State wise Sales Distribution in Crore
state_wise_sales=((sql_data.groupby(["state"])["total_sales_after_discount_crore"].sum())).reset_index()
state_wise_sales
# Out:
#                 state  total_sales_after_discount_crore
# 0      Andhra Pradesh                            575.29
# 1               Bihar                            231.21
# 2               Delhi                            713.49
# 3                 Goa                            269.16
# 4             Gujarat                            878.61
# 5             Haryana                            137.08
# 6    Himachal Pradesh                             62.22
# 7   Jammu and Kashmir                            267.35
# 8           Karnataka                            341.07
# 9             Kerala                             168.39
# 10     Madhya Pradesh                           2476.36
# 11        Maharashtra                           1727.02
# 12           Nagaland                            700.28
# 13             Punjab                            881.41
# 14          Rajasthan                            549.22
# 15             Sikkim                             49.92
# 16         Tamil Nadu                            293.57
# 17      Uttar Pradesh                            698.60
# 18        West Bengal                            106.36

# %%
# Bar Plot
plt.figure(figsize=(10,10))
barplot=sns.barplot(data=state_wise_sales, x="total_sales_after_discount_crore",y="state",hue="state",palette="Set1")
for container in barplot.containers:
    barplot.bar_label(container) # values at edgeof each bar(for loop con each containers in bar plot)
plt.title("State wise Total Sales After Discount In Crore Distribution")
plt.xlabel("Total Sales After Discount In Crore")
plt.ylabel("State")
barplot.set_xlim(0, 3000) # min and max limit od Y axis
plt.show()

# %% [markdown]
# **Observations**:
#
# - From **DataFrame Analysis** we conclude that **Madhya Pradessh State** has maximum Number of **Total Sales in Crore** (**2476.36**) .
# - From **DataFrame Analysis** we conclude that **Sikkim State** has minimum Number of **Total Sales in Crore** (**49.92**) .

# %% [markdown]
# ### City Wise Mobile Sales Amount Distribution

# %%
# Data Set of Flipkart Mobile
sql_data.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  ...  discount_percent  \
# 0           4.7                1                 1  ...              17.0
# 1           5.4                2                 1  ...               4.0
# 2           4.7                1                 1  ...              17.0
# 3           6.1                1                 1  ...              10.0
# 4           6.1                2                 1  ...               2.0
#
#    discount_amount  sale_price_after_discount  \
# 0          5609.83                   27389.17
# 1          2285.96                   54863.04
# 2          5609.83                   27389.17
# 3          4299.90                   38699.10
# 4          1382.98                   67766.02
#
#    total_sales_before_discount_crore  total_sales_after_discount_crore  \
# 0                             127.52                            105.84
# 1                               1.39                              1.33
# 2                             127.52                            105.84
# 3                              23.07                             20.76
# 4                               5.15                              5.05
#
#    unit_of_sales  payment_method           state     city  ratings_category
# 0        38644.0             UPI   Uttar Pradesh  Mathura         Very Good
# 1          243.0     Credit Card           Delhi    Delhi         Very Good
# 2        38644.0     Net Banking   Uttar Pradesh  Mathura         Very Good
# 3         5365.0             UPI     Maharashtra   Mumbai       Outstanding
# 4          745.0             COD  Madhya Pradesh   Indore       Outstanding
#
# [5 rows x 25 columns]

# %%
# City wise Sales Distribution in Crore
city_wise_sales=((sql_data.groupby(["city"])["total_sales_after_discount_crore"].sum())).reset_index()
city_wise_sales
# Out:
#                   city  total_sales_after_discount_crore
# 0            Ahmedabad                            812.27
# 1             Amritsar                            110.41
# 2            Bangalore                            341.07
# 3               Bhopal                            582.48
# 4           Chandigarh                            908.08
# 5              Chennai                            293.57
# 6                Delhi                            713.49
# 7              Gangtok                             49.92
# 8                  Goa                            269.16
# 9            Hyderabad                            575.29
# 10              Indore                           1893.88
# 11              Jaipur                            165.37
# 12             Kashmir                            267.35
# 13              Kohima                            700.28
# 14             Kolkata                            106.36
# 15             Lucknow                            393.87
# 16             Mathura                            271.29
# 17              Mumbai                           1407.73
# 18               Patna                            231.21
# 19           Prayagraj                             33.44
# 20                Pune                            319.29
# 21               Simla                             62.22
# 22               Surat                             66.34
# 23  Thiruvananthapuram                            168.39
# 24             Udaipur                            383.85

# %%
# Bar Plot
plt.figure(figsize=(10,10))
barplot=sns.barplot(data=city_wise_sales, x="total_sales_after_discount_crore",y="city",hue="city",palette="Set1")
for container in barplot.containers:
    barplot.bar_label(container) # values at edgeof each bar(for loop con each containers in bar plot)
plt.title("City wise Total Sales After Discount In Crore Distribution")
plt.xlabel("Total Sales After Discount In Crore")
plt.ylabel("State")
barplot.set_xlim(0, 2500) # min and max limit od Y axis
plt.show()

# %% [markdown]
# **Observations**:
#
# - From **DataFrame Analysis** we conclude that **Indoor City** has maximum Number of **Total Sales in Crore** (**1893.88**) .
# - From **DataFrame Analysis** we conclude that **Prayagraj City** has minimum Number of **Total Sales in Crore** (**33.44**) .

# %% [markdown]
# ### Zone Wise Sales Distribution

# %%
# Data Set of Flipkart Mobile
sql_data.head()
# Out:
#    brand           model base_color processor screen_size  ROM  RAM  \
# 0  Apple       iPhone SE      Black     Water  Very Small   64    2
# 1  Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2  Apple       iPhone SE        Red     Water  Very Small   64    2
# 3  Apple       iPhone XR     Others       iOS      Medium   64    3
# 4  Apple       iPhone 12        Red   Ceramic      Medium  128    4
#
#    display_size  num_rear_camera  num_front_camera  ...  discount_percent  \
# 0           4.7                1                 1  ...              17.0
# 1           5.4                2                 1  ...               4.0
# 2           4.7                1                 1  ...              17.0
# 3           6.1                1                 1  ...              10.0
# 4           6.1                2                 1  ...               2.0
#
#    discount_amount  sale_price_after_discount  \
# 0          5609.83                   27389.17
# 1          2285.96                   54863.04
# 2          5609.83                   27389.17
# 3          4299.90                   38699.10
# 4          1382.98                   67766.02
#
#    total_sales_before_discount_crore  total_sales_after_discount_crore  \
# 0                             127.52                            105.84
# 1                               1.39                              1.33
# 2                             127.52                            105.84
# 3                              23.07                             20.76
# 4                               5.15                              5.05
#
#    unit_of_sales  payment_method           state     city  ratings_category
# 0        38644.0             UPI   Uttar Pradesh  Mathura         Very Good
# 1          243.0     Credit Card           Delhi    Delhi         Very Good
# 2        38644.0     Net Banking   Uttar Pradesh  Mathura         Very Good
# 3         5365.0             UPI     Maharashtra   Mumbai       Outstanding
# 4          745.0             COD  Madhya Pradesh   Indore       Outstanding
#
# [5 rows x 25 columns]

# %%
# read table data using sql query 
sql_data2 = pd.read_sql_query(text("select * from flipkart_mobile_2;"),con =engine.connect()) # new Data Set Importing in Pandas from DataBase
sql_data2
# Out:
#        Distinct_state    Zone
# 0       Uttar Pradesh  Cental
# 1               Delhi   North
# 2         Maharashtra    West
# 3      Madhya Pradesh  Cental
# 4      Andhra Pradesh   South
# 5             Gujarat    West
# 6               Bihar    East
# 7    Himachal Pradesh   North
# 8              Punjab    West
# 9             Kerala    South
# 10           Nagaland    East
# 11            Haryana    West
# 12          Rajasthan    West
# 13          Karnataka   South
# 14         Tamil Nadu   South
# 15        West Bengal    East
# 16  Jammu and Kashmir   North
# 17                Goa    West
# 18             Sikkim    East

# %%
# Rename the Column of the DataFrame
sql_data2.rename(columns={'Distinct_state': 'state'}, inplace=True)
sql_data2
# Out:
#                 state    Zone
# 0       Uttar Pradesh  Cental
# 1               Delhi   North
# 2         Maharashtra    West
# 3      Madhya Pradesh  Cental
# 4      Andhra Pradesh   South
# 5             Gujarat    West
# 6               Bihar    East
# 7    Himachal Pradesh   North
# 8              Punjab    West
# 9             Kerala    South
# 10           Nagaland    East
# 11            Haryana    West
# 12          Rajasthan    West
# 13          Karnataka   South
# 14         Tamil Nadu   South
# 15        West Bengal    East
# 16  Jammu and Kashmir   North
# 17                Goa    West
# 18             Sikkim    East

# %%
zone_wise_data = sql_data.merge(sql_data2,on="state",how="inner")
zone_wise_data
# Out:
#        brand           model base_color processor screen_size  ROM  RAM  \
# 0      Apple       iPhone SE      Black     Water  Very Small   64    2
# 1      Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2      Apple       iPhone SE        Red     Water  Very Small   64    2
# 3      Apple       iPhone XR     Others       iOS      Medium   64    3
# 4      Apple       iPhone 12        Red   Ceramic      Medium  128    4
# ..       ...             ...        ...       ...         ...  ...  ...
# 425  Samsung      Galaxy A20      Black    Exynos      Medium   32    3
# 426  Samsung   Galaxy A22 5G     Others  MediaTek       Large  128    8
# 427  Samsung     Galaxy F02s       Blue  Qualcomm       Large   32    3
# 428  Samsung      Galaxy F62       Blue    Exynos       Large  128    8
# 429  Samsung      Galaxy F41      Green    Exynos      Medium  128    6
#
#      display_size  num_rear_camera  num_front_camera  ...  discount_amount  \
# 0             4.7                1                 1  ...          5609.83
# 1             5.4                2                 1  ...          2285.96
# 2             4.7                1                 1  ...          5609.83
# 3             6.1                1                 1  ...          4299.90
# 4             6.1                2                 1  ...          1382.98
# ..            ...              ...               ...  ...              ...
# 425           6.4                2                 1  ...          1149.00
# 426           6.6                3                 1  ...          1759.92
# 427           6.5                3                 1  ...           854.91
# 428           6.7                4                 1  ...          4679.82
# 429           6.4                3                 1  ...          4349.70
#
#      sale_price_after_discount  total_sales_before_discount_crore  \
# 0                     27389.17                             127.52
# 1                     54863.04                               1.39
# 2                     27389.17                             127.52
# 3                     38699.10                              23.07
# 4                     67766.02                               5.15
# ..                         ...                                ...
# 425                   10341.00                              17.83
# 426                   20239.08                               0.06
# 427                    8644.09                               0.65
# 428                   21319.18                              12.34
# 429                   10149.30                              89.62
#
#      total_sales_after_discount_crore  unit_of_sales  payment_method  \
# 0                              105.84        38644.0             UPI
# 1                                1.33          243.0     Credit Card
# 2                              105.84        38644.0     Net Banking
# 3                               20.76         5365.0             UPI
# 4                                5.05          745.0             COD
# ..                                ...            ...             ...
# 425                             16.05        15518.0     Credit Card
# 426                              0.06           27.0             COD
# 427                              0.59          684.0             UPI
# 428                             10.12         4746.0             COD
# 429                             62.73        61811.0      Debit Card
#
#               state       city  ratings_category    Zone
# 0     Uttar Pradesh    Mathura         Very Good  Cental
# 1             Delhi      Delhi         Very Good   North
# 2     Uttar Pradesh    Mathura         Very Good  Cental
# 3       Maharashtra     Mumbai       Outstanding    West
# 4    Madhya Pradesh     Indore       Outstanding  Cental
# ..              ...        ...               ...     ...
# 425         Gujarat      Surat              Good    West
# 426  Andhra Pradesh  Hyderabad               Bad   South
# 427  Madhya Pradesh     Indore              Good  Cental
# 428           Bihar      Patna              Good    East
# 429        Nagaland     Kohima               Bad    East
#
# [430 rows x 26 columns]

# %%
# Zone wise Sales Distribution in Crore
zone_wise_sales_distribution=((zone_wise_data.groupby(["Zone"])["total_sales_after_discount_crore"].sum())).reset_index()
zone_wise_sales_distribution
# Out:
#      Zone  total_sales_after_discount_crore
# 0  Cental                           3174.96
# 1    East                           1087.77
# 2   North                           1043.06
# 3   South                           1378.32
# 4    West                           4442.50

# %%
# Bar Plot
plt.figure(figsize=(10,5))
barplot=sns.barplot(data=zone_wise_sales_distribution, x="Zone",y="total_sales_after_discount_crore",hue="Zone",palette="Set1")
for container in barplot.containers:
    barplot.bar_label(container) # values at edgeof each bar(for loop con each containers in bar plot)
plt.title("Zone wise Total Sales Distribution")
plt.xlabel("Zone")
plt.ylabel("Total Sales in Crore")
barplot.set_ylim(0, 5000) # min and max limit od Y axis
plt.show()

# %% [markdown]
# **Observations**:
#
# - We have **5 Zone Groups** with in the data set => **Cental** , **East** , **North** , **South** , **West** .
# - From **DataFrame Analysis** we conclude that **West Zone** has maximum Number of **Total Sales in Crore** (**4442.50**) .
# - From **DataFrame Analysis** we conclude that **North Zone** has minimum Number of **Total Sales in Crore** (**1043.06**) .

# %% [markdown]
# <a id=section6></a>
#
# ---
# # **6. Conclusion**
# ---

# %% [markdown]
# <a id=section61></a>
#
# ---
# ## **6.1 Summarization**
# ---

# %% [markdown]
# ---
# - **Mobile Brand Groups:**
# ---
# - We have **5 Brand Groups** with in the data set => **Apple** , **Poco** , **Realme** , **Samsung** , **Xiaomi** .
#
# ---
# - **Key Columns and Types:**
# ---
# - We have **Categorical Data:** brand, model, base_color, processor, screen_size, zone, state, city, payment method.
# - We have **Numerical Data:** Includes both continuous and discrete data:
# - We have **Continuous Data:** display_size, ratings, discount_percent, sales.
# - We have **Discrete Data:** ROM, RAM, num_rear_camera, num_front_camera, battery_capacity, num_of_ratings, sales_price.
#
# ---
# - **Statistical Highlights:**
# ---
# - **Storage (ROM)**: Ranges from **8 GB** to **512 GB**, with a median of **128 GB**.
# - **RAM**: Ranges from **1 GB** to **12 GB**, median of **4 GB**.
# - **Battery Capacity**: Varies between **1800 mAh** and **7000 mAh**.
# - **Sales Price**: Minimum **₹5742**, maximum **₹1,57,999**, median around **₹16,990**.
# - **Ratings**: Range from **3.0** to **4.6**, averaging **4.34**.
#
# ---
# - **Zone/State/City Highlights:**
# ---
# - We have **5 Zone Groups** within the data set => **Cental** , **East** , **North** , **South** , **West** .
# - We have **19 State Groups** within the data set and we conclude that **Madhya Pradessh** State has **maximum Number** of **Total Sales in Crore (2476.36)** and **Sikkim State** has **minimum Number** of **Total Sales in Crore (49.92)**.
# - We have **25 City Groups** within the data set and we conclude that **Indoor City** has **maximum Number** of **Total Sales in Crore (1893.88)** and **Prayagraj City** has **minimum Number** of **Total Sales in Crore (33.44)**
#
# ---
# - **Payment Method Highlights:**
# ---
# - We have **5 Payment Method Groups** within the data set => **COD** , **Credit Card** , **Debit Card** , **Net Banking** , **UPI** .
# - We conclude that maximum **Unit of Sales in Thousand** (**2657.462 Thousands in COD**) & minimum **Unit of Sales in Thousand** (**1375.742 Thousands in UPI**).

# %% [markdown]
# <a id=section62></a>
#
# ---
# ## **6.2 Actionable Insights**
# ---
#
# - We need a more clean dataset, specially the one which has precise and accurate information.
#
# - We also need data from **secondary sources** that describe more about the **Price**, the **Processor**, the **RAM**, the **ROM**, the **Battery Capacity** of mobiles being listed.
#
# - Knowing about the **type of Processor**, **type of RAM**, **Battery Capacity** or **type of ROM** will also be helpful to determine if it affects the price of mobiles.
#
# - **Price** is **highly related** to **Processor**, **RAM, ROM** and, **Battery Capacity**.
#
# - We can use this lot of information to **predict the prices of mobile**, although **Processor** is an **important factor** and we need more information on that.
#
# - The company can use **this information** and **extrapolate** some of the observations throughout the price listings.
